# %% [markdown]
# ### Problema del XOR:

# %%
import numpy as np
from mlp.mlp_main import MLP
from mlp_sgd.MLP import SgdMLP
import matplotlib.pyplot as plt

# %%
inputs_bits = np.array(
    [
        [0, 0],
        [1, 0],
        [0, 1],
        [1, 1],
    ]
)

output_XOR = np.array([0, 1, 1, 0])

# %% [markdown]
# #### MLP with SGD:

# %%
mlp_sgd = SgdMLP(
    layers=[(2, 3, "leaky_relu"), (3, 2, "leaky_relu"), (2, 1, "sigmoid")],
    learning_rate=0.5,
)

# %%
error = mlp_sgd.train(inputs_bits, output_XOR, epochs=5000, error_tolerance=0.01)
# Out:
# Epoch 1, MSE: 0.2567984072057961
# Epoch 101, MSE: 0.17413800815705086
# Epoch 201, MSE: 0.17358450570030157
# Epoch 301, MSE: 0.1730770131728696
# Epoch 401, MSE: 0.1729027357766309
# Epoch 501, MSE: 0.1726123413736476
# Epoch 601, MSE: 0.17235320037309315
# Epoch 701, MSE: 0.17210361370702248
# Epoch 801, MSE: 0.1718530431731096
# Epoch 901, MSE: 0.17159083816800766
# Epoch 1001, MSE: 0.17141066995490878
# Epoch 1101, MSE: 0.17130637583548677
# Epoch 1201, MSE: 0.17122245338345257
# Epoch 1301, MSE: 0.1711104829868817
# Epoch 1401, MSE: 0.17104713645376493
# Epoch 1501, MSE: 0.17099102115500445
# Epoch 1601, MSE: 0.17090413642523608
# Epoch 1701, MSE: 0.17085286843289227
# Epoch 1801, MSE: 0.17076681227762341
# Epoch 1901, MSE: 0.17070943636046007
# Epoch 2001, MSE: 0.17061187036566536
# Epoch 2101, MSE: 0.17053495472076977
# Epoch 2201, MSE: 0.17044209591618936
# Epoch 2301, MSE: 0.17029016790333032
# Epoch 2401, MSE: 0.17010796960853433
# Epoch 2501, MSE: 0.16991498684677278
# Epoch 2601, MSE: 0.1696680217493064
# Last epoch: 2679 with MSE: 0.009832148344957842

# %%
for x, y in zip(inputs_bits, output_XOR):
    y_pred = mlp_sgd.predict(x)
    binary = 1 if y_pred[0] >= 0.5 else 0
    print(f"Input: {x} | Esperado: {y} | Predicho: {binary}")
# Out:
# Input: [0 0] | Esperado: 0 | Predicho: 0
# Input: [1 0] | Esperado: 1 | Predicho: 1
# Input: [0 1] | Esperado: 1 | Predicho: 1
# Input: [1 1] | Esperado: 0 | Predicho: 0

# %%
# Plot error trace
plt.plot(error)
plt.xlabel("Epoch")
plt.ylabel("Mean Squared Error")
plt.title("Training Error")
plt.show()

# %% [markdown]
# ### MLP with Backpropagation implementation

# %%
# Instancia
mlp = MLP(
    layers=[(2, 3, "leaky_relu"), (3, 2, "leaky_relu"), (2, 1, "sigmoid")],
    learning_rate=0.5,
)

# %%
error_mlp = mlp.train(inputs_bits, output_XOR, epochs=5000, error_tolerance=0.01, batch_size=4)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[11], line 1
# ----> 1 error_mlp = mlp.train(inputs_bits, output_XOR, epochs=5000, error_tolerance=0.01, batch_size=4)
#
# File d:\WORKSPACE\Projs\MLP\AI & ML Personal Learning Project\src\mlp\mlp_main.py:53, in MLP.train(self, X, y, epochs, batch_size, error_tolerance)
#      50     loss = 0.5 * np.sum((y_batch - y_pred) ** 2)
#      51     epoch_loss += loss
# ---> 53     self.backward(X_batch, y_batch)
#      55 # MSE global por época
#      56 mse = epoch_loss / len(X)
#
# File d:\WORKSPACE\Projs\MLP\AI & ML Personal Learning Project\src\mlp\mlp_main.py:79, in MLP.backward(self, X, y)
#      74 delta = (y - self.layers[-1].function(z_last_layer)) * self.layers[-1].function(z_last_layer, True)
#      77 a_last_layer = self.layers[-1].input_x if len(self.layers) > 1 else X
# ---> 79 self.layers[-1].matrix += self.learning_rate * np.dot(a_last_layer.T, delta)
#      80 self.layers[-1].biases += self.learning_rate * np.sum(delta, axis=0, keepdims=True)
#      83 for i in range(len(self.layers) - 2, -1, -1):
#
# ValueError: non-broadcastable output operand with shape (2,1) doesn't match the broadcast shape (2,4)

# %%
plt.plot(error_mlp)
plt.title("Error a lo largo de las épocas")
plt.xlabel("Época")
plt.ylabel("Error (MSE)")
plt.show()
